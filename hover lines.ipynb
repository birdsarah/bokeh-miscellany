# %%
from bokeh.charts import Line, output_notebook, show
from bokeh.models import HoverTool
from bokeh.plotting import figure, ColumnDataSource
from bokeh.palettes import Spectral6
import pandas as pd
import numpy as np
from itertools import cycle
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86b2a5a1-f3f2-41eb-860d-0b83143fbec6">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

colors = Spectral6
colorcycler = cycle(colors)

source = ColumnDataSource(df)
p = figure(plot_width=800, plot_height=400)

for column in df.columns:
    line = p.line(
        x=df.index, y=column, source=source, 
        line_color=next(colorcycler), line_width=5, line_cap='round', line_join='round'
    )
    p.add_tools(HoverTool(tooltips=[("x,y","$x,$y"),("column", "&nbsp;%s" % column),], renderers=[line]))

show(p)
# Out:
#     <div class="plotdiv" id="9aa9fe59-13a6-42a6-bee5-307a99a32f99"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9aa9fe59-13a6-42a6-bee5-307a99a32f99");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9aa9fe59-13a6-42a6-bee5-307a99a32f99' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"48a42e46-ab4d-4b09-9602-a775d267cf56":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"C"}},"id":"d7232a7d-1bab-4f03-bc8c-35de74621f94","type":"Line"},{"attributes":{"line_cap":"round","line_color":{"value":"red"},"line_join":"round","line_width":{"value":10},"x":{"field":"x"},"y":{"field":"B"}},"id":"9ea3339c-599c-4fe1-b7a7-98c8dd229e6e","type":"Line"},{"attributes":{"plot":{"id":"87f57efe-0f27-405f-b094-bcdba17d0ddb","subtype":"Figure","type":"Plot"}},"id":"a5e0eefc-19a8-41ad-8630-db00c9196785","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":10},"x":{"field":"x"},"y":{"field":"E"}},"id":"1d8017bf-dd54-4515-b207-8b2e09cc2259","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"C"}},"id":"7852d732-ff65-4764-93f0-991ca8712dc9","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"A"}},"id":"86c8ca5e-bba8-41c2-b54d-38bad6a4854a","type":"Line"},{"attributes":{"callback":null},"id":"6409fdae-59e8-423b-beec-35ca914dc86f","type":"DataRange1d"},{"attributes":{"line_width":{"value":10},"x":{"field":"x"},"y":{"field":"E"}},"id":"f8bd4112-5403-4284-998e-a633a7be84ff","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"E"}},"id":"d6bc2843-20c4-4489-8c1f-a6bffc144fb4","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"A"}},"id":"d72a037f-b581-46f6-8f22-f132837e7d30","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4fe4ff43-5207-4e85-8882-f3c5b3f88e77","type":"BoxAnnotation"},{"attributes":{"line_cap":"round","line_color":{"value":"#d7191c"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"D"}},"id":"712dac68-21ee-4cbe-af76-2cc46408d77b","type":"Line"},{"attributes":{},"id":"e7571a81-917b-4759-987c-c93b2f70e723","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"9d6649ad-f477-4a34-b200-36c8288fdbe6","subtype":"Figure","type":"Plot"},"renderers":[{"id":"97739c0a-8034-4f48-8473-83aa25633027","type":"GlyphRenderer"}],"tooltips":[["x,y","$x,$y"],["column","B"]]},"id":"e2e942ba-c046-4d93-b520-32ff691879f0","type":"HoverTool"},{"attributes":{"plot":{"id":"3c161247-7ee6-4374-973f-f3a8a7cb2369","subtype":"Figure","type":"Plot"}},"id":"6f2cb0d6-cb57-47ca-94b9-1ba9b9564b42","type":"PanTool"},{"attributes":{"callback":null,"column_names":["C","B","A","E","index","D","x","x","x","x","x"],"data":{"A":[0.8236692594909989,0.03383136402136855,0.8656553568792701,0.09554149367459186,0.7964221707306668,0.6746049332812758,0.002622196232335172,0.8788152254200446,0.24543487973497835,0.38065650812149177],"B":[0.5049917465652326,0.7954380181418892,0.5167045558525276,0.15317931929953832,0.9285934097140166,0.32740536881548843,0.4032478734545457,0.2981159027580389,0.630190023705612,0.25687533166157195],"C":[0.7775378510452483,0.7154084508502795,0.3637172510466431,0.6698369414197157,0.40870172284319806,0.72028958198759,0.8128168329650493,0.3321375794607767,0.8335628256218526,0.23648744735726046],"D":[0.3656825869834358,0.4288989901415965,0.3935814168283269,0.8666279537821451,0.33410234226838464,0.4192109876768366,0.8674271887829842,0.19695798785470797,0.048126696024507365,0.33 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>
