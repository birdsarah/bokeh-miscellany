# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2755fd6e-6485-49d5-bcca-f8fb911f210d">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Scatter
from bokeh.sampledata.autompg import autompg as df
from bokeh.models import Range1d

x_range = Range1d(20, 30)

# %%
range_in_call = Scatter(df, x='mpg', title="x='mpg'", xlabel="Miles Per Gallon", x_range=x_range, plot_height=200)
show(range_in_call)
# Out:
#     <div class="plotdiv" id="a5566961-e388-45ef-9d43-ec1d9dfa702b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a5566961-e388-45ef-9d43-ec1d9dfa702b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a5566961-e388-45ef-9d43-ec1d9dfa702b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8a66bb0e-cab8-4254-ac92-9503351a85cf":{"roots":{"references":[{"attributes":{"data_source":{"id":"4925e57b-b93a-4e06-848d-65de738c8aeb","type":"ColumnDataSource"},"glyph":{"id":"19db55a6-0388-473d-9161-b2d48452c8ec","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"64c465e3-bc72-4b44-b45a-c35b1e667cbc","type":"GlyphRenderer"},{"attributes":{},"id":"337d0068-7c88-4802-b00e-7858a2de48a2","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"}},"id":"c683866b-77bd-4be5-95ba-74ce65a45378","type":"HelpTool"},{"attributes":{"callback":null,"end":50.36,"start":5.24},"id":"13270fb4-042e-4a4e-9593-795aa3d0d826","type":"Range1d"},{"attributes":{"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"}},"id":"a3a3f488-0203-4332-99dd-2395a09c09ea","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ed4017fa-0f87-4ec3-9217-0dabced852fb","type":"Circle"},{"attributes":{"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"},"ticker":{"id":"8562db67-e3a4-406a-8e55-5659a36faf82","type":"BasicTicker"}},"id":"1cb2279a-fe09-40fa-afff-ce57bdc1ef37","type":"Grid"},{"attributes":{"plot":{"id":"a4d1a515-8b1a-4d57-8537-6cdf62a182ad","subtype":"Chart","type":"Plot"}},"id":"d80d09e2-6b3b-46db-85f6-2465977244cc","type":"ResizeTool"},{"attributes":{},"id":"d9ca6028-2822-4125-af19-19d1432ca8c6","type":"BasicTicker"},{"attributes":{"formatter":{"id":"db5e8d40-eeca-47cd-af26-4234686f76d5","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"a4d1a515-8b1a-4d57-8537-6cdf62a182ad","subtype":"Chart","type":"Plot"},"ticker":{"id":"98cf3ced-1421-4586-8459-e9faeaba8271","type":"CategoricalTicker"}},"id":"b31a5926-444f-4f54-82ce-c5844469332b","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"c98be3ec-a1b3-4ae5-a600-e2b0942f1f55","type":"ColumnDataSource"},"glyph":{"id":"ed4017fa-0f87-4ec3-9217-0dabced852fb","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c56c55ad-c897-48d7-b16a-b97797d73a07","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"},"ticker":{"id":"337d0068-7c88-4802-b00e-7858a2de48a2","type":"CategoricalTicker"}},"id":"027b620e-30b7-4558-b12e-35948374831d","type":"Grid"},{"attributes":{"plot":{"id":"a4d1a515-8b1a-4d57-8537-6cdf62a182ad","subtype":"Chart","type":"Plot"}},"id":"0d7f3496-fc0a-4110-93f1-cae4a7c8f6e5","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %%
range_after = Scatter(df, x='mpg', title="x='mpg'", xlabel="Miles Per Gallon", plot_height=200)
range_after.x_range = x_range
show(range_after)
# Out:
#     <div class="plotdiv" id="582f29e5-ec34-43ff-9168-86e69f15846c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("582f29e5-ec34-43ff-9168-86e69f15846c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '582f29e5-ec34-43ff-9168-86e69f15846c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"522efa69-99e9-4a79-a5c8-5311640f7103":{"roots":{"references":[{"attributes":{"overlay":{"id":"c2cd5a20-3ac5-4b58-acb8-a0b063198c43","type":"BoxAnnotation"},"plot":{"id":"43d9bfcd-356e-4aac-afd4-bbb0ea8ed43d","subtype":"Chart","type":"Plot"}},"id":"d27e0c6b-b864-498b-a0be-39aad60f2f52","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"d461f495-ea03-4c5a-bf8d-93219953bc46","type":"LinearAxis"}],"left":[{"id":"a5253d69-5be4-47f8-b59c-bab47d161e68","type":"CategoricalAxis"}],"legend":null,"plot_height":200,"renderers":[{"id":"c2cd5a20-3ac5-4b58-acb8-a0b063198c43","type":"BoxAnnotation"},{"id":"8899a356-b93f-4126-8b4b-6e22a54bb87b","type":"GlyphRenderer"},{"id":"d461f495-ea03-4c5a-bf8d-93219953bc46","type":"LinearAxis"},{"id":"a5253d69-5be4-47f8-b59c-bab47d161e68","type":"CategoricalAxis"},{"id":"7883b6b4-042f-4c49-9b0d-410bd3d8d2fb","type":"Grid"},{"id":"32892c48-2e19-4e7d-88ac-96f322b5f49e","type":"Grid"}],"title":"x='mpg'","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"008475b7-bf1a-4579-a87b-50bef3713eca","type":"ToolEvents"},"tools":[{"id":"9607eaac-ecf1-4629-a39a-071a0e6675b6","type":"PanTool"},{"id":"499f903c-4769-4e37-bfae-0b72463588ab","type":"WheelZoomTool"},{"id":"d27e0c6b-b864-498b-a0be-39aad60f2f52","type":"BoxZoomTool"},{"id":"c127e643-5f17-4c94-bfec-b7141011ab47","type":"PreviewSaveTool"},{"id":"37137908-4630-4d57-a078-9ea295620e0a","type":"ResizeTool"},{"id":"644ad1bd-a515-4d08-9fc7-ab320299470f","type":"ResetTool"},{"id":"491bd1c0-3427-4c8a-9651-71cebe74fb22","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":"db07f683-ea89-40d4-b854-5214896d7fd3","type":"Range1d"},"xscale":"auto","y_mapper_type":"auto","y_range":{"id":"cdb21c44-94e3-4361-a38c-588a053a51b6","type":"FactorRange"},"yscale":"auto"},"id":"43d9bfcd-356e-4aac-afd4-bbb0ea8ed43d","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"4925e57b-b93a-4e06-848d-65de738c8aeb","type":"ColumnDataSource"},"glyph":{"id":"19db55a6-0388-473d-9161-b2d48452c8ec","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"64c465e3-bc72-4b44-b45a-c35b1e667cbc","type":"GlyphRenderer"},{"attributes":{},"id":"f3370f92-3040-4c7b-94e4-7c919ed34803","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"}},"id":"c683866b-77bd-4be5-95ba-74ce65a45378","type":"HelpTool"},{"attributes":{},"id":"337d0068-7c88-4802-b00e-7858a2de48a2","type":"CategoricalTicker"},{"attributes":{"callback":null,"end":50.36,"start":5.24},"id":"13270fb4-042e-4a4e-9593-795aa3d0d826","type":"Range1d"},{"attributes":{"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"}},"id":"a3a3f488-0203-4332-99dd-2395a09c09ea","type":"PanTool"},{"attributes":{"callback":null,"factors":["None"]},"id":"cdb21c44-94e3-4361-a38c-588a053a51b6","type":"FactorRange"},{"attributes":{"dimension":1,"plot":{"id":"a4d1a515-8b1a-4d57-8537-6cdf62a182ad","subtype":"Chart","type":"Plot"},"ticker":{"id":"98cf3ced-1421-4586-8459-e9faeaba8271","type":"CategoricalTicker"}},"id":"0610915e-dadf-4577-892a-c32ede74625f","type":"Grid"},{"attributes":{"plot":{"id":"43d9bfcd-356e-4aac-afd4-bbb0ea8ed43d","subtype":"Chart","type":"Plot"},"ticker":{"id":"e65d21e7-763d-4cb4-937c-f76f62a20e63","type":"BasicTicker"}},"id":"7883b6b4-042f-4c49-9b0d-410bd3d8d2fb","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ed4017fa-0f87-4ec3-9217-0dabced852fb","type":"Circle"},{"attributes":{},"id":"2c8191b8-3126-41d6-966f-462365b7f032","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"end":30,"start":20},"id":"db07f683-ea89-40d4-b854-5214896d7fd3","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"5c472fed-a610-4f84-a39d-bc4b1037fdaa","subtype":"Chart","type":"Plot"},"ticker":{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>
