# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="54a5d691-ac06-49d4-bfb4-a300877e4b25">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.plotting import figure, show
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p = figure(plot_width=600, plot_height=300, tools=["pan, hover, reset"],
               y_range=(1, 8), y_axis_label='asdasd', toolbar_location='above', logo=None,)
p.line(x, y, line_width=2)
p1 = figure(plot_width=600, plot_height=300, tools=["pan, hover, reset"],
               y_range=(1, 8), y_axis_label='asdasd', toolbar_location='above', logo=None,)
p1.line(x, y, line_width=2)
t = Tabs(tabs=[Panel(child=p, title='asd'), Panel(child=p1, title='asdasd')])
show(t)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="aacf7fc1-0856-4f39-ab9e-dbfc05d13531"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aacf7fc1-0856-4f39-ab9e-dbfc05d13531");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aacf7fc1-0856-4f39-ab9e-dbfc05d13531' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"17127c5b-eca5-411b-bc05-fab77090f620":{"roots":{"references":[{"attributes":{"below":[{"id":"e535d89d-4dec-4686-9c7e-c30dcab12107","type":"LinearAxis"}],"left":[{"id":"1ed3b551-64c1-4711-814c-d6ef930acbfc","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"e535d89d-4dec-4686-9c7e-c30dcab12107","type":"LinearAxis"},{"id":"f17df32b-91e5-482f-8a81-7b2ce0c59efe","type":"Grid"},{"id":"1ed3b551-64c1-4711-814c-d6ef930acbfc","type":"LinearAxis"},{"id":"99fe4390-c21d-42cb-8387-17bf892a2427","type":"Grid"},{"id":"ef651fcb-044d-447f-a3a4-f329e00af8eb","type":"GlyphRenderer"}],"title":{"id":"44752d62-ffdc-46a8-b622-2e4bee737fcf","type":"Title"},"tool_events":{"id":"1b35d8e6-3ef5-4bd3-aa87-f08788c13eff","type":"ToolEvents"},"toolbar":{"id":"cc63fb03-16c9-49f4-afdf-c4ac267f4978","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"82a6c2bb-1d7e-4140-8145-853a250466c3","type":"DataRange1d"},"y_range":{"id":"a68f7546-e702-409e-9402-e3cc48666dc3","type":"Range1d"}},"id":"697dd5f4-f935-4381-99a7-9d5c5b8bcc80","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"327e9630-814c-474a-bdce-a5abdbdfd9cc","type":"BasicTickFormatter"},{"attributes":{},"id":"fcf469e7-09d4-4403-8cc1-6755d97afff9","type":"BasicTickFormatter"},{"attributes":{"axis_label":"asdasd","formatter":{"id":"067431f8-8da2-44b9-b17f-07fbf46c1b42","type":"BasicTickFormatter"},"plot":{"id":"9b37bb66-eded-4b19-82c4-0a5cfeab5c5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"d788bc9f-2926-44aa-b952-7a8b75438ef6","type":"BasicTicker"}},"id":"a8fd86a4-d764-44f0-8141-1de6e3d465f2","type":"LinearAxis"},{"attributes":{"plot":{"id":"697dd5f4-f935-4381-99a7-9d5c5b8bcc80","subtype":"Figure","type":"Plot"},"ticker":{"id":"473abbd7-6e8b-4123-90cb-06e0485dfc65","type":"BasicTicker"}},"id":"f17df32b-91e5-482f-8a81-7b2ce0c59efe","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8efb453f-4e69-4941-b517-2815463d37a6","type":"Line"},{"attributes":{},"id":"74d06269-bf76-4f9d-b039-81d1e3a831f2","type":"BasicTicker"},{"attributes":{"data_source":{"id":"81480a15-c21a-4be4-a57c-72e7f5eb4c43","type":"ColumnDataSource"},"glyph":{"id":"46a7fd9b-10cd-4b51-a72f-ba5f7e74f178","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8efb453f-4e69-4941-b517-2815463d37a6","type":"Line"},"selection_glyph":null},"id":"d6e5a9bf-987f-45a8-a4d9-7d4c71228978","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"7f7d3e13-ead7-4465-8691-b5531c8f8422","type":"DataRange1d"},{"attributes":{"plot":{"id":"697dd5f4-f935-4381-99a7-9d5c5b8bcc80","subtype":"Figure","type":"Plot"}},"id":"b667a82d-02b5-49b5-82f1-5b44c9cb9444","type":"ResetTool"},{"attributes":{"below":[{"id":"e77aa8f0-1f77-4111-a8bb-069fc6b574c9","type":"LinearAxis"}],"left":[{"id":"a8fd86a4-d764-44f0-8141-1de6e3d465f2","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"e77aa8f0-1f77-4111-a8bb-069fc6b574c9","type":"LinearAxis"},{"id":"5c8627c3-a584-4cd1-a769-489dc6f8c80f","type":"Grid"},{"id":"a8fd86a4-d764-44f0-8141-1de6e3d465f2","type":"LinearAxis"},{"id":"2ec7f3a3-9b63-4b90-95fa-64ad189d4195","type":"Grid"},{"id":"d6e5a9bf-987f-45a8-a4d9-7d4c71228978","type":"GlyphRenderer"}],"title":{"id":"64b62b37-a4c3-4f8b-a177-13e5b3d5e9b2","type":"Title"},"tool_events":{"id":"a12ef7a6-8db4-473d-b7e9-f3be4f2fad1f","type":"ToolEvents"},"toolbar":{"id":"4428219e-5e09-4edc-924a-cb3ae7184f9d","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"7f7d3e13-ead7-4465-8691-b5531c8f8422","type":"DataRange1d"},"y_range":{"id":"16ed4fdc-c9d5-45c2-8110-c9d0c3fe9623","type":"Range1d"}},"id":"9b37bb66-eded-4b19-82c4-0a5cfeab5c5c","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"74518238-c3e5-4287-9a87-7bbefbed62ef","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"697dd5f4-f935-4381-99a7-9d5c5b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p = figure(plot_width=400, plot_height=300, tools=["pan, hover, reset"],
               y_range=(1, 8), y_axis_label='asdasd', toolbar_location='above', logo=None)
p.line(x, y, line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="367db0cc-25a1-476c-a8fb-c2cdfce2fd85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("367db0cc-25a1-476c-a8fb-c2cdfce2fd85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '367db0cc-25a1-476c-a8fb-c2cdfce2fd85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8bfde789-d8a7-4a9b-8725-05dbc145b066":{"roots":{"references":[{"attributes":{"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"}},"id":"31c60bb6-e66f-4284-82a8-9cbeadb74898","type":"PanTool"},{"attributes":{"callback":null,"end":8,"start":1},"id":"31fd6fa1-956c-4011-9c6d-0074788f235d","type":"Range1d"},{"attributes":{"below":[{"id":"b64f1a5e-a56b-43ab-8316-185619f13492","type":"LinearAxis"}],"left":[{"id":"d962887d-cbfa-4734-a8ab-9898d4fa6aee","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"b64f1a5e-a56b-43ab-8316-185619f13492","type":"LinearAxis"},{"id":"57988359-58fe-420c-8f00-e849a0579cf7","type":"Grid"},{"id":"d962887d-cbfa-4734-a8ab-9898d4fa6aee","type":"LinearAxis"},{"id":"89e5ccb2-f7a6-4fd5-a611-dd40dd75e4ec","type":"Grid"},{"id":"554f0c9d-ac01-4272-a11c-51a0f82e8911","type":"GlyphRenderer"}],"title":{"id":"4a6c394a-d76e-4dff-aa73-ed0954ca7fb8","type":"Title"},"tool_events":{"id":"954caaff-3181-42d5-bb66-b0d123fe1793","type":"ToolEvents"},"toolbar":{"id":"3fd1db4b-2da1-4fc4-be2a-82fff2442b87","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"6c741241-6d36-4266-bbae-71eafef98a55","type":"DataRange1d"},"y_range":{"id":"31fd6fa1-956c-4011-9c6d-0074788f235d","type":"Range1d"}},"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"c16dbd22-e800-476e-ba7f-04b5c5974654","type":"BasicTickFormatter"},"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5ab870-fd9d-4673-91e5-03cb89c2b2ff","type":"BasicTicker"}},"id":"b64f1a5e-a56b-43ab-8316-185619f13492","type":"LinearAxis"},{"attributes":{"callback":null},"id":"6c741241-6d36-4266-bbae-71eafef98a55","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"}},"id":"a778121e-f1fe-4c7d-99cb-e627ffe6e4b1","type":"HoverTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"651677b1-521f-4156-b270-27859f985581","type":"Line"},{"attributes":{},"id":"62579453-db0e-4b68-a4f5-f406d04fe954","type":"BasicTickFormatter"},{"attributes":{"axis_label":"asdasd","formatter":{"id":"62579453-db0e-4b68-a4f5-f406d04fe954","type":"BasicTickFormatter"},"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"},"ticker":{"id":"43173cf4-e18c-4bc9-81ba-96eff5acd278","type":"BasicTicker"}},"id":"d962887d-cbfa-4734-a8ab-9898d4fa6aee","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"},"ticker":{"id":"43173cf4-e18c-4bc9-81ba-96eff5acd278","type":"BasicTicker"}},"id":"89e5ccb2-f7a6-4fd5-a611-dd40dd75e4ec","type":"Grid"},{"attributes":{},"id":"c16dbd22-e800-476e-ba7f-04b5c5974654","type":"BasicTickFormatter"},{"attributes":{},"id":"fc5ab870-fd9d-4673-91e5-03cb89c2b2ff","type":"BasicTicker"},{"attributes":{},"id":"954caaff-3181-42d5-bb66-b0d123fe1793","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"4a6c394a-d76e-4dff-aa73-ed0954ca7fb8","type":"Title"},{"attributes":{"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"}},"id":"fc78b254-a979-4476-8163-d1feb05f609c","type":"ResetTool"},{"attributes":{},"id":"43173cf4-e18c-4bc9-81ba-96eff5acd278","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","logo":null,"tools":[{"id":"31c60bb6-e66f-4284-82a8-9cbeadb74898","type":"PanTool"},{"id":"a778121e-f1fe-4c7d-99cb-e627ffe6e4b1","type":"HoverTool"},{"id":"fc78b254-a979-4476-8163-d1feb05f609c","type":"ResetTool"}]},"id":"3fd1db4b-2da1-4fc4-be2a-82fff2442b87","type":"Toolbar"},{"attributes":{"plot":{"id":"e75dfa34-5241-4123-ba9b-ded65cad347a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5ab870-fd9d-4673-91e5-03cb89c2b2ff","type ...
#             var render_items = [{"docid":"8bfde789-d8a7-4a9b-8725-05dbc145b066","elementid":"367db0cc-25a1-476c-a8fb-c2cdfce2fd85","modelid":"e75dfa34-5241-4123-ba9b-ded65cad347a","notebook_comms_target":"da71fb64-da55-4745-afbe-2978cc9f77e2"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>
