# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.palettes import Spectral4

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a2fb74d2-5069-4ff2-ba00-0f68d460864d">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(tools='hover')
p.circle(
    x=[1, 2, 3, 4],
    y=[2, 4, 5, 6],
    radius=0.5,
    fill_color=Spectral4, line_color=None, fill_alpha=0.6,
    hover_fill_color='pink', hover_line_color=None, hover_fill_alpha=0.1,
)
show(p)
# Out:
#     <div class="plotdiv" id="61265be0-4e7d-45ab-8e9a-bce77e499bf8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61265be0-4e7d-45ab-8e9a-bce77e499bf8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61265be0-4e7d-45ab-8e9a-bce77e499bf8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"46a43554-1848-4c75-8a6d-fac45bc86e86":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c518d17-88f9-4057-81f9-14ff701fbe1a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"radius":{"units":"data","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1342d752-04ff-4c05-a924-5be75dd04332","type":"Circle"},{"attributes":{"formatter":{"id":"77eed8b1-5737-4596-9081-ae0c1e0a4d66","type":"BasicTickFormatter"},"plot":{"id":"c228dbf7-ca33-494d-bc4e-da38e9a9cf55","subtype":"Figure","type":"Plot"},"ticker":{"id":"151c82fc-d126-458f-85d6-5cac5c0367db","type":"BasicTicker"}},"id":"1ab3e29c-22aa-4b74-9b03-11e79d91c449","type":"LinearAxis"},{"attributes":{"below":[{"id":"8cd3b44c-5dc2-4a47-8768-3ca95c5e3bc8","type":"LinearAxis"}],"left":[{"id":"024370d5-fcf8-447e-991c-ba31da5c166d","type":"LinearAxis"}],"renderers":[{"id":"8cd3b44c-5dc2-4a47-8768-3ca95c5e3bc8","type":"LinearAxis"},{"id":"f36437e8-32b5-4249-be1c-c5e0f9e01521","type":"Grid"},{"id":"024370d5-fcf8-447e-991c-ba31da5c166d","type":"LinearAxis"},{"id":"03b31035-6fb3-4208-81cf-5a60bb2b4b61","type":"Grid"},{"id":"e3871a79-dff2-4d9c-94d4-e7f8a8166c09","type":"GlyphRenderer"}],"tool_events":{"id":"01a14792-0a75-43ca-bea1-97a912929232","type":"ToolEvents"},"tools":[{"id":"e4aa57b4-e364-40f8-8a8c-fb03190c5ff5","type":"HoverTool"}],"x_range":{"id":"41f22590-cf81-4e1e-ae1d-5e866e5286a2","type":"DataRange1d"},"y_range":{"id":"05e494d8-64dc-4f9e-9eb5-b53d604d9069","type":"DataRange1d"}},"id":"138d6463-2e55-4b5c-a9db-0e67899f776d","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"00d64497-2741-4f83-9883-8fe196a5b3d2","type":"BasicTickFormatter"},{"attributes":{},"id":"7418783a-59ad-4be7-a668-c6b8e750bf6a","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ec73e645-eb57-4801-ad81-56e28b134992","type":"DataRange1d"},{"attributes":{},"id":"a505c399-a3d4-4a52-b06d-3deaafb57319","type":"ToolEvents"},{"attributes":{"formatter":{"id":"e16cfbd6-f2d0-4bc9-ab54-53d0f4895c41","type":"BasicTickFormatter"},"plot":{"id":"f51a0a98-14a2-468a-9d95-00fd75dccf27","subtype":"Figure","type":"Plot"},"ticker":{"id":"1573be87-dce6-4d50-b686-cadb2c137834","type":"BasicTicker"}},"id":"7fde5521-0901-4c6c-a9a2-15d054f41cde","type":"LinearAxis"},{"attributes":{"formatter":{"id":"6d6af170-c375-4049-957a-d1c84e578691","type":"BasicTickFormatter"},"plot":{"id":"138d6463-2e55-4b5c-a9db-0e67899f776d","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8a9a143-6a31-43cc-a0c3-00d34b281a81","type":"BasicTicker"}},"id":"8cd3b44c-5dc2-4a47-8768-3ca95c5e3bc8","type":"LinearAxis"},{"attributes":{"formatter":{"id":"b8095aaa-c787-4667-8ae0-fd82fb93f853","type":"BasicTickFormatter"},"plot":{"id":"08cf4dbf-691d-4252-9feb-c6969411af29","subtype":"Figure","type":"Plot"},"ticker":{"id":"f952d475-d6c9-4161-b0d9-e8db15a194ae","type":"BasicTicker"}},"id":"72f98ee6-045e-446c-8242-0536ca49d9a4","type":"LinearAxis"},{"attributes":{"callback":null},"id":"6ef7c0b5-d65c-4280-ae74-c53cd2e1532b","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"d957efd9-30ad-4619-8b49-a8afef972d89","subtype":"Figure","type":"Plot"}},"id":"487b0c7c-08ea-4caa-ae2a-0b76060c7d04","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7be1144d-15b4-438a-bd0a-278093def234","type":"Circle"},{"attributes":{},"id":"a8c68d29-1d67-4004-a353-dd37a10ebf9d","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"value":"pink"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb638ef1-5305-4701-97c8-0a75ead24778","type":"Circle"},{"attributes":{"formatter":{"id ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
p = figure(tools='hover')
p.circle(
    x=[1, 2, 3, 4],
    y=[2, 4, 5, 6],
    radius=0.5,
    fill_color=Spectral4, line_color=None, fill_alpha=0.6,
    hover_fill_color=Spectral4, hover_line_color=None, hover_fill_alpha=0.1,
)
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ac2274fc1d9c> in <module>()
#       5     radius=0.5,
#       6     fill_color=Spectral4, line_color=None, fill_alpha=0.6,
# ----> 7     hover_fill_color=Spectral4, hover_line_color=None, hover_fill_alpha=0.1,
#       8 )
#       9 show(p)
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/plotting/helpers.py in func(self, *args, **kwargs)
#     468         glyph = _make_glyph(glyphclass, kwargs, glyph_ca)
#     469         nsglyph = _make_glyph(glyphclass, kwargs, nsglyph_ca)
# --> 470         hglyph = _make_glyph(glyphclass, kwargs, hglyph_ca)
#     471         sglyph = _make_glyph(glyphclass, kwargs, sglyph_ca)
#     472
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/plotting/helpers.py in _make_glyph(glyphclass, kws, extra)
#     129         kws = kws.copy()
#     130         kws.update(extra)
# --> 131         return glyphclass(**kws)
#     132
#     133 def _update_legend(plot, legend_name, glyph_renderer):
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/model.py in __init__(self, **kwargs)
#      81         self._id = kwargs.pop("id", make_id())
#      82         self._document = None
# ---> 83         super(Model, self).__init__(**kwargs)
#      84         default_theme.apply_to_model(self)
#      85
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in __init__(self, **properties)
#     699
#     700         for name, value in properties.items():
# --> 701             setattr(self, name, value)
#     702
#     703     def __setattr__(self, name, value):
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in __setattr__(self, name, value)
#     712
#     713         if name in props or name in deprecated:
# --> 714             super(HasProps, self).__setattr__(name, value)
#     715         else:
#     716             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in __set__(self, obj, value)
#     451             raise RuntimeError("Cannot set a property value '%s' on a %s instance before HasProps.__init__" %
#     452                                (self.name, obj.__class__.__name__))
# --> 453         value = self.descriptor.prepare_value(obj.__class__, self.name, value)
#     454
#     455         old = self.__get__(obj)
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in prepare_value(self, cls, name, value)
#     270                     break
#     271             else:
# --> 272                 raise e
#     273         else:
#     274             value = self.transform(value)
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in prepare_value(self, cls, name, value)
#     263     def prepare_value(self, cls, name, value):
#     264         try:
# --> 265             self.validate(value)
#     266         except ValueError as e:
#     267             for tp, converter in self.alternatives:
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in validate(self, value)
#    1845                 return True
#    1846             else:
# -> 1847                 raise e
#    1848
#    1849     def transform(self, value):
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in validate(self, value)
#    1839     def validate(self, value):
#    1840         try:
# -> 1841             return super(ColorSpec, self).validate(value)
#    1842         except ValueError as e:
#    1843             # Check for tuple input if not yet a valid input type
#
# /Users/caged/miniconda3/envs/bokeh_miscellany/lib/python3.5/site-packages/bokeh/core/properties.py in validate(self, value)
#    1296
#    1297         if not (value is None or any(param.is_valid(value) for param in self.type_params)):
# -> 1298             raise ValueError("expected an element of either %s, got %r" % (nice_join(self.type_params), value))
#    1299
#    1300     def transform(self, value):
#
# ValueError: expected an element of either String, Dict(String, Either(String, Color)) or Color, got ['#2b83ba', '#abdda4', '#fdae61', '#d7191c']

# %%
p = figure(tools='hover')
source = ColumnDataSource(
    {
        'x': [1, 2, 3, 4],
        'y': [2, 4, 5, 6],     
        'color': Spectral4,
    }
)
p.circle(
    x='x',
    y='y',
    radius=0.5,
    fill_color='color', line_color=None, fill_alpha=0.5,
    hover_fill_color='color', hover_line_color=None, hover_fill_alpha=0.9,
    source=source
)
show(p)
# Out:
#     <div class="plotdiv" id="4c590b15-95a3-490a-9ef5-b746d1e1cbd0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c590b15-95a3-490a-9ef5-b746d1e1cbd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c590b15-95a3-490a-9ef5-b746d1e1cbd0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5924cbc2-bc62-4409-8fc5-e6cb878df491":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c518d17-88f9-4057-81f9-14ff701fbe1a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.9},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"radius":{"units":"data","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1342d752-04ff-4c05-a924-5be75dd04332","type":"Circle"},{"attributes":{"formatter":{"id":"77eed8b1-5737-4596-9081-ae0c1e0a4d66","type":"BasicTickFormatter"},"plot":{"id":"c228dbf7-ca33-494d-bc4e-da38e9a9cf55","subtype":"Figure","type":"Plot"},"ticker":{"id":"151c82fc-d126-458f-85d6-5cac5c0367db","type":"BasicTicker"}},"id":"1ab3e29c-22aa-4b74-9b03-11e79d91c449","type":"LinearAxis"},{"attributes":{"below":[{"id":"8cd3b44c-5dc2-4a47-8768-3ca95c5e3bc8","type":"LinearAxis"}],"left":[{"id":"024370d5-fcf8-447e-991c-ba31da5c166d","type":"LinearAxis"}],"renderers":[{"id":"8cd3b44c-5dc2-4a47-8768-3ca95c5e3bc8","type":"LinearAxis"},{"id":"f36437e8-32b5-4249-be1c-c5e0f9e01521","type":"Grid"},{"id":"024370d5-fcf8-447e-991c-ba31da5c166d","type":"LinearAxis"},{"id":"03b31035-6fb3-4208-81cf-5a60bb2b4b61","type":"Grid"},{"id":"e3871a79-dff2-4d9c-94d4-e7f8a8166c09","type":"GlyphRenderer"}],"tool_events":{"id":"01a14792-0a75-43ca-bea1-97a912929232","type":"ToolEvents"},"tools":[{"id":"e4aa57b4-e364-40f8-8a8c-fb03190c5ff5","type":"HoverTool"}],"x_range":{"id":"41f22590-cf81-4e1e-ae1d-5e866e5286a2","type":"DataRange1d"},"y_range":{"id":"05e494d8-64dc-4f9e-9eb5-b53d604d9069","type":"DataRange1d"}},"id":"138d6463-2e55-4b5c-a9db-0e67899f776d","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"00d64497-2741-4f83-9883-8fe196a5b3d2","type":"BasicTickFormatter"},{"attributes":{},"id":"7418783a-59ad-4be7-a668-c6b8e750bf6a","type":"BasicTicker"},{"attributes":{"callback":null},"id":"4661ac92-1a52-4f10-bb93-f4133e5932f3","type":"DataRange1d"},{"attributes":{},"id":"c9fe2d35-d660-4922-ab18-59c4f5ecf40c","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ec73e645-eb57-4801-ad81-56e28b134992","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6fb0f0e-20a5-4272-bda1-d5d9b4996de1","type":"Circle"},{"attributes":{"formatter":{"id":"e16cfbd6-f2d0-4bc9-ab54-53d0f4895c41","type":"BasicTickFormatter"},"plot":{"id":"f51a0a98-14a2-468a-9d95-00fd75dccf27","subtype":"Figure","type":"Plot"},"ticker":{"id":"1573be87-dce6-4d50-b686-cadb2c137834","type":"BasicTicker"}},"id":"7fde5521-0901-4c6c-a9a2-15d054f41cde","type":"LinearAxis"},{"attributes":{},"id":"08735e95-7503-479d-8092-3b74087ac901","type":"BasicTicker"},{"attributes":{"formatter":{"id":"b8095aaa-c787-4667-8ae0-fd82fb93f853","type":"BasicTickFormatter"},"plot":{"id":"08cf4dbf-691d-4252-9feb-c6969411af29","subtype":"Figure","type":"Plot"},"ticker":{"id":"f952d475-d6c9-4161-b0d9-e8db15a194ae","type":"BasicTicker"}},"id":"72f98ee6-045e-446c-8242-0536ca49d9a4","type":"LinearAxis"},{"attributes":{"callback":null},"id":"3147b416-ca1f-4c18-8f07-ee1eb862360c","type":"DataRange1d"},{"attributes":{},"id":"cea1b0aa-93eb-4473-915f-2b689880e114","type":"ToolEvents"},{"attributes":{"callback":null},"id":"6ef7c0b5-d65c-4280-ae74-c53cd2e1532b","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"873d2cb0-cfef-4106-bc07-d1b61a705834","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7be1144d-15b4-438a-bd0a-278093def234","typ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[21]</strong>&gt;</code></p>
