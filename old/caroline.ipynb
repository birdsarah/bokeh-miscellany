# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, TextInput, DatetimeTickFormatter, FactorRange
from bokeh.io import output_notebook, show 
from bokeh.layouts import widgetbox, layout
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7544556f-d20e-4ad4-b496-f43e6fc8674d">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_height=600)

# configure x axis
p.x_range = FactorRange()
p.xaxis[0].formatter = DatetimeTickFormatter(formats=dict(
    hours=["%Y-%m-%d"],
    days=["%Y-%m-%d"],
    months=["%Y-%m-%d"],
    years=["%Y-%m-%d"],
))


source = ColumnDataSource(data=dict(x=[], y=[]))
r = p.circle(x='x', y='y', source=source)


from_date = TextInput(value='2016-03-01',
                      title='Please enter the starting date in the format of yyyy-mm-dd')
to_date = TextInput(value='2016-04-30',
                    title='Please enter the ending date in the format of yyyy-mm-dd')


def update_plot(attr, old, new):
  d_range = pd.date_range(from_date.value.strip(), to_date.value.strip()).strftime('%Y-%m-%d')

  p.plot_width = 25 + len(d_range) * 65 + 25

  print(p.plot_width)

  p.x_range.factors = d_range.tolist()
  p.xaxis[0].ticker = CategoricalTicker(tags=d_range.tolist())
  p.xgrid[0].ticker = CategoricalTicker(tags=d_range.tolist()) 

  ds2.data = dict(...)


from_date.on_change('value', update_plot)
to_date.on_change('value', update_plot)


controls = [from_date, to_date]
w_box = widgetbox(controls, width=200, sizing_mode='fixed')
# page_layout = row(w_box, p)
page_layout = layout(children=[[w_box, p]])

# %%
show(page_layout)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ed04e9c7-7789-4d3e-be2f-1e82c489891d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ed04e9c7-7789-4d3e-be2f-1e82c489891d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ed04e9c7-7789-4d3e-be2f-1e82c489891d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"080f777f-a8e0-4c6e-b68a-ea058a7e0ed4":{"roots":{"references":[{"attributes":{"children":[{"id":"f87aa3ea-22b5-4048-964c-ff0eda37a54c","type":"TextInput"},{"id":"d04ce75e-2b8d-45e3-8c59-3f6e48259cc9","type":"TextInput"}],"width":200},"id":"2988a977-469b-440e-8890-aa684b470ac1","type":"WidgetBox"},{"attributes":{"below":[{"id":"9b91fb39-d434-4826-a7f7-446f1dee9df9","type":"LinearAxis"}],"left":[{"id":"c2cf401f-ef07-448d-9031-76439a17cbb1","type":"LinearAxis"}],"renderers":[{"id":"9b91fb39-d434-4826-a7f7-446f1dee9df9","type":"LinearAxis"},{"id":"e2db2acf-d0b1-495f-a04a-f93fe98954a4","type":"Grid"},{"id":"c2cf401f-ef07-448d-9031-76439a17cbb1","type":"LinearAxis"},{"id":"99ceabdd-bf41-49b1-a64f-3a4db1a86354","type":"Grid"},{"id":"16d6174d-c7d1-412c-927e-886500ad1386","type":"BoxAnnotation"},{"id":"9355e811-4f0c-420f-9543-74621eb7785b","type":"GlyphRenderer"}],"title":{"id":"9c11af9b-1c11-4d02-98ea-29edece7d7ec","type":"Title"},"tool_events":{"id":"af0cfaab-010e-4024-ba9f-91b4ad9de6f2","type":"ToolEvents"},"toolbar":{"id":"1fdcb1c9-a6f9-4d85-8ac6-fe3ecebc828f","type":"Toolbar"},"x_range":{"id":"fd30e78a-28ed-45b2-9d62-f440581653f9","type":"FactorRange"},"y_range":{"id":"b43b2cb9-a7e6-4f89-873e-6ca7befa6899","type":"DataRange1d"}},"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e4f08d97-3d92-47af-bace-d4056250ae96","type":"Circle"},{"attributes":{"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"c5d853cc-1a69-403f-8942-944bad79c17a","type":"BasicTicker"}},"id":"e2db2acf-d0b1-495f-a04a-f93fe98954a4","type":"Grid"},{"attributes":{"children":[{"id":"2988a977-469b-440e-8890-aa684b470ac1","type":"WidgetBox"},{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}]},"id":"e813cfb4-9461-4f71-9e77-c1a4883738a9","type":"Row"},{"attributes":{"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}},"id":"718ad3e5-54af-4948-91fe-a7fa97669fde","type":"SaveTool"},{"attributes":{"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}},"id":"fd31c703-56c4-4edc-ab09-cd1c2863d13a","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"16d6174d-c7d1-412c-927e-886500ad1386","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"16d6174d-c7d1-412c-927e-886500ad1386","type":"BoxAnnotation"},"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}},"id":"6fb265ee-26e6-44e9-9b89-ba1132cb79e1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}},"id":"eff78e13-0b6f-4943-9746-c5d1e4002f97","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"997a93e0-376c-4730-a4ba-e2f095b7104d","type":"BasicTicker"}},"id":"99ceabdd-bf41-49b1-a64f-3a4db1a86354","type":"Grid"},{"attributes":{},"id":"c5d853cc-1a69-403f-8942-944bad79c17a","type":"BasicTicker"},{"attributes":{"callback":null,"title":"Please enter the ending date in the format of yyyy-mm-dd","value":"2016-04-30"},"id":"d04ce75e-2b8d-45e3-8c59-3f6e48259cc9","type":"TextInput"},{"attributes":{"callback":null},"id":"b43b2cb9-a7e6-4f89-873e-6ca7befa6899","type":"DataRange1d"},{"attributes":{"callback":null},"id":"fd30e78a-28ed-45b2-9d62-f440581653f9","type":"FactorRange"},{"attributes":{"plot":{"id":"eb588133-68b6-4c44-af69-95cd714248f1","subtype":"Figure","type":"Plot"}}," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>
