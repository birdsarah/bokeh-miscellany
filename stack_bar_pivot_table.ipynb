# %%
from bokeh.io import output_notebook, show
from bokeh.charts import Bar
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e1e191a5-9548-4f0a-949e-afe691ff3e56">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
from numpy.random import randint

# %%
index = pd.Index([1,2,3,4,5], label='period')
columns = pd.Index(['A', 'B', 'C'], label='categories')
values = randint(10, 100, 15).reshape(5, 3)
values.sort(axis=0)
df = pd.DataFrame(values, index, columns)
original_df = df.copy()

# %%
original_df
# Out:
#     A   B   C
# 1  15  12  23
# 2  26  12  31
# 3  45  48  66
# 4  53  48  75
# 5  82  64  89

# %%
list(randint(10, 100, 15))
# Out:
# [48, 36, 84, 29, 92, 70, 46, 26, 23, 15, 14, 60, 87, 26, 66]

# %%
data = {
    'period': [1, 2, 3, 4, 5] * 3,
    'cat': ['A' ,'B', 'C'] * 5,
    'value': list(randint(10, 100, 15))
}
long_df = pd.DataFrame(data)
long_df = long_df.sort_values(by='cat')
long_df.head()
# Out:
#    cat  period  value
# 0    A       1     33
# 3    A       4     46
# 6    A       2     20
# 9    A       5     63
# 12   A       3     73

# %%
show(Bar(long_df, label='period', values='value', stack='cat', legend=True))
# Out:
#     <div class="plotdiv" id="776f1ea0-136c-49d6-8916-ea76cec3f5f6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("776f1ea0-136c-49d6-8916-ea76cec3f5f6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '776f1ea0-136c-49d6-8916-ea76cec3f5f6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"004001b4-4700-4c44-9faf-26ccd7d871b5":{"roots":{"references":[{"attributes":{"data_source":{"id":"a7157f0b-14bd-4d54-b29f-5687833ccc2c","type":"ColumnDataSource"},"glyph":{"id":"d18a84f5-5640-457e-9d92-739364666024","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a97097a9-f98d-4eeb-a23c-92a9e6999c7d","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"88b3d3eb-ef7c-4b7f-88eb-75441b8fc46d","type":"CategoricalAxis"}],"left":[{"id":"1ec18d99-ce6b-4690-86c8-79b3763474b9","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"a78ac920-5dd4-472f-ac5f-b8231f78c5dd","type":"BoxAnnotation"},{"id":"c9628811-5833-4198-a0f8-632cb8507111","type":"GlyphRenderer"},{"id":"fe1ba495-03bc-4397-8857-91f69cbbc126","type":"GlyphRenderer"},{"id":"d9b0d40d-675b-4427-b74c-2a2fa9747754","type":"GlyphRenderer"},{"id":"88b3d3eb-ef7c-4b7f-88eb-75441b8fc46d","type":"CategoricalAxis"},{"id":"1ec18d99-ce6b-4690-86c8-79b3763474b9","type":"LinearAxis"},{"id":"3587d2b0-9152-47c0-bc5e-5f7c0623aeb8","type":"Grid"}],"title_text_font_size":{"value":"14pt"},"tool_events":{"id":"625f3bb8-32e7-48c9-b020-850bccb37456","type":"ToolEvents"},"tools":[{"id":"f2c5e3a6-2f66-4059-b86c-ff42d4b1e1ab","type":"PanTool"},{"id":"417fd8d2-be06-4d00-af7c-4ae9471be0c1","type":"WheelZoomTool"},{"id":"226425f4-aafa-41a0-93a1-2f553fcfe5ae","type":"BoxZoomTool"},{"id":"538b76fd-6162-44d9-80ab-dd844604c60e","type":"PreviewSaveTool"},{"id":"870a1615-0bdc-411b-8f21-5c512070df03","type":"ResizeTool"},{"id":"456787a2-2878-46b1-8065-54ee3f21b01a","type":"ResetTool"},{"id":"2eeef4f2-417d-4888-9331-0e628aecee0a","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":"21f8c649-bf5b-4418-b03a-3738e2dd99ac","type":"FactorRange"},"xgrid":false,"xscale":"auto","y_mapper_type":"auto","y_range":{"id":"f36c0708-d471-4eab-93a5-43370603ca71","type":"Range1d"},"yscale":"auto"},"id":"d000ee65-6b06-44f6-b28a-208434dec06e","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","fill_alpha","color","line_alpha","width","height","y","line_color"],"data":{"cat":["C"],"chart_index":[{"cat":"C","period":4}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[34.0],"line_alpha":[1.0],"line_color":["white"],"period":[4],"width":[0.8],"x":["4"],"y":[35.0]}},"id":"8b5199e8-6ec2-4cc0-94e2-10d87f13c380","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e24cab6f-55e1-409a-88f4-1317fae7ef6c","type":"Rect"},{"attributes":{},"id":"eea08908-3d19-446d-97f0-5253ac34fa7d","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"27bd242f-ce53-4569-b415-9694fe08c9f7","subtype":"Chart","type":"Plot"}},"id":"27842143-d829-4154-9cc9-f56545694666","type":"ResizeTool"},{"attributes":{},"id":"e96e7da0-1537-4ec4-a4b3-68a9807b7047","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a618bf11-b41d-4ffa-8851-c84cb4135cfb","type":"Rect"},{"attributes":{"plot":{"id":"c8533a65-4ac7-4b14-8bc4-fc2520a3628b","subtype":"Chart","type":"Plot"}},"id":"ed9c24cd-2ca4-4dac-b2ff-3b96a9bcfc57","type":"ResetTool"},{"attributes":{"data_source":{"id":"2d2f9190-cfb5-431e-8415-516ff2dce678","type":"ColumnDataSource"},"glyph":{"id":"0468a9b0-8a59-491b-a37e-1b9f5c58c088","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3b34893c-9f0b-4280-bbe4-36a193757bc4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[44]</strong>&gt;</code></p>
