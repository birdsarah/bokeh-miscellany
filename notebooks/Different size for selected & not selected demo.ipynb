# %%
from IPython.display import IFrame, display, HTML

import pandas as pd
import numpy as np

from bokeh.models import ColumnDataSource, Plot, Circle, Range1d, LinearAxis, TapTool, HoverTool, Text
from bokeh.embed import file_html
from bokeh.plotting import vplot
from bokeh.resources import CDN
from bokeh.models.actions import Callback
from bokeh.models.widgets import Slider

# %% [markdown]
# ### Get the Data

# %%
# Links via http://www.gapminder.org/data/ 

population_url = "http://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&output=xls"
fertility_url = "http://spreadsheets.google.com/pub?key=phAwcNAVuyj0TAlJeCEzcGQ&output=xls"
life_expectancy_url = "http://spreadsheets.google.com/pub?key=tiAiXcrneZrUnnJ9dBU-PAw&output=xls"

def get_data(url):
    # Get the data from the url and return only 1962 - 2013
    df = pd.read_excel(url, index_col=0)
    df = df.unstack().unstack()
    df = df[(df.index >= 1962) & (df.index <= 2013)]
    df = df.unstack().unstack()    
    return df

fertility_df = get_data(fertility_url)
life_expectancy_df = get_data(life_expectancy_url)
population_df = get_data(population_url)

# have common countries across all data
fertility_df = fertility_df.drop(fertility_df.index.difference(life_expectancy_df.index))
population_df = population_df.drop(population_df.index.difference(life_expectancy_df.index))

# get a size value based on population, but don't let it get too small
population_df_size = np.sqrt(population_df/np.pi)/200
min_size = 3
population_df_size = population_df_size.where(population_df_size >= min_size).fillna(min_size)

# %% [markdown]
# Start setting up the plot

# %%
sources = {}

for i, country in enumerate(fertility_df.index):
    fertility = fertility_df.loc[country]
    fertility.name = 'fertility'
    life = life_expectancy_df.loc[country]
    life.name = 'life' 
    population = population_df_size.loc[country]
    population.name = 'population' 
    new_df = pd.concat([fertility, life, population], axis=1)
    new_df['country'] = country
    sources['_' + str(i)] = ColumnDataSource(new_df)
    
years = list(fertility_df.columns)

xdr = Range1d(1, 8)
ydr = Range1d(20, 85)
plot = Plot(
    x_range=xdr,
    y_range=ydr,
    title="",
    plot_width=800,
    plot_height=400,
    outline_line_color=None,
    toolbar_location=None,
)
xaxis = LinearAxis()
yaxis = LinearAxis()   
plot.add_layout(xaxis, 'left')
plot.add_layout(yaxis, 'below')
tooltips = "@index<br />@country"
plot.add_tools(HoverTool(tooltips=tooltips))
default_selection = {
        '0d': {'flag': False, 'indices': []},
        '1d': {'indices': [0]},
        '2d': {'indices': []}
    }

# %% [markdown]
# # Set the selection & nonselection glyph sizes differently

# %%
for source in sources.values():
    source.selected = default_selection
    empty_circle = Circle(x='fertility', y='life', fill_color='#444444', line_color=None, fill_alpha=0.2, size=5)
    red_circle = Circle(x='fertility', y='life', fill_color='#F6931F', line_color='#995a13', size=25)
    plot.add_glyph(source, empty_circle, selection_glyph=red_circle, nonselection_glyph=empty_circle)

# %% [markdown]
# Finish plotting

# %%
javascript_list_of_sources = str(list(sources.keys())).replace("'", "")

    
code = """
    var years = %s;
    var new_selection = years.indexOf(slider.get('value'));
    var new_selection_object = {'indices': [new_selection]};
    var sources = %s;

    sources.forEach(function(s) {
        s.attributes.selected['1d'] = new_selection_object;
        s.trigger('change');
    });
""" % (years, javascript_list_of_sources)


callback = Callback(args=sources, code=code)
slider = Slider(start=1962, end=2013, value=1, step=1, title="Year", callback=callback)
callback.args["slider"] = slider

layout = vplot(plot, slider)
html = file_html(layout, CDN, "gapminder")
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>gapminder</title>
#
#         <link rel="stylesheet" href="http://cdn.pydata.org/bokeh/dev/bokeh-0.9.1dev.65161924.min.css" type="text/css" />
#         <script type="text/javascript" src="http://cdn.pydata.org/bokeh/dev/bokeh-0.9.1dev.65161924.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#         <script type="text/javascript">
#             Bokeh.$(function() {
#                 var modelid = "5b469720-1053-4c1f-8970-cd54b47beda2";
#                 var modeltype = "VBox";
#                 var elementid = "3d06977f-5a19-44e5-b7e7-3eee78d5fd90";
#                 Bokeh.logger.info("Realizing plot:")
#                 Bokeh.logger.info(" - modeltype: VBox");
#                 Bokeh.logger.info(" - modelid: 5b469720-1053-4c1f-8970-cd54b47beda2");
#                 Bokeh.logger.info(" - elementid: 3d06977f-5a19-44e5-b7e7-3eee78d5fd90");
#                 var all_models = [{"attributes": {"x": {"field": "fertility"}, "fill_alpha": {"value": 0.2}, "tags": [], "y": {"field": "life"}, "line_color": null, "size": {"units": "screen", "value": 5}, "id": "99658a8e-5b06-48a3-a484-71465d1ed9ca", "fill_color": {"value": "#444444"}, "doc": null}, "type": "Circle", "id": "99658a8e-5b06-48a3-a484-71465d1ed9ca"}, {"attributes": {"x": {"field": "fertility"}, "tags": [], "y": {"field": "life"}, "line_color": {"value": "#995a13"}, "size": {"units": "screen", "value": 25}, "id": "4cb4d58e-2c21-41d5-8d9b-c0a42b501fd7", "fill_color": {"value": "#F6931F"}, "doc": null}, "type": "Circle", "id": "4cb4d58e-2c21-41d5-8d9b-c0a42b501fd7"}, {"attributes": {"selected": {"1d": {"indices": [0]}, "2d": {"indices": []}, "0d": {"indices": [], "flag": false}}, "callback": null, "column_names": ["index", "fertility", "population", "country", "life"], "tags": [], "doc": null, "id": "0c19ecd9-341d-481b-93cb-b645c043d537", "data": {"index": [1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], "fertility": [7.168, 7.19, 7.192, 7.165, 7.101, 6.998, 6.86, 6.69, 6.498, 6.293, 6.089, 5.895, 5.716, 5.556, 5.414, 5.283, 5.157, 5.036, 4.917, 4.802, 4.69, 4.581, 4.472, 4.362, 4.248, 4.128, 4.002, 3.872, 3.738, 3.601, 3.466, 3.335, 3.212, 3.1, 3.005, 2.926, 2.862, 2.81, 2.765, 2.718, 2.665, 2.602, 2.529, 2.449, 2.367, 2.292, 2.229, 2.179, 2.142, 2.115, 2.094, 2.075], "population": [3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.050771378123349, 3.1688111147271134, 3.2453592836936536, 3.2891393844688714, 3.310587605977253], "country": ["Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain"], "life": [54.588, 55.91, 57.182, 58.389, 59.526, 60.599, 61.611, 62.562, 63.45, 64.276, 65.043, 65.757, 66.421, 67.04, 67.615, 68.151, 68.65, 69.116, 69.549, 69.95, 70.319, 70.656, 70.965, 71.248, 71.507, 71.745, 71.967, 72.177, 72.382, 72.587, 72.794, 73.004, 73.22, 73.439, 73.661, 73.879, 74.092, 74.298, 74.497, 74.69, 74.879, 75.064, 75.247, 75.424, 75.595, 75.759, 75.914, 76.062, 76.203, 76.339, 76.474, 76.608]}}, "type": "ColumnDataSource", "id": "0c19ecd9-341d-481b-93cb-b645c043d537"}, {"attributes": {"selection_glyph": {"type": "Circle", "id": "09057b44-36f2-432e-ade0-19352a0e58c3"}, "tags": [], "data_source": {"type": "ColumnDataSource", "id": "605a01c6-0978-487b-9151-f1d2404e698c"}, "nonselection_glyph": {"type": "Circle", "id": "2610f78e-882e-4135-8aa3-6091d65921c1"}, "glyph": {"type": "Circle", "id": "2610f78e-882e-4135-8aa3-6091d65921c1"}, "id": "4297391a-47c3-4e41-afb2-f5b3683f4236", "doc": null}, "type": "GlyphRenderer", "id": "4297391a-47c3-4e41-afb2-f5b3683f4236"}, {"attributes": {"x": {"field": "fertility"}, "tags": [], "y": {"field": "life"}, "line_color": {"value": "#995a13"}, "size": {"units": "screen", "value": 25}, "id": "e7239980-5faf-4dfc-bb9c-d4046a0adebd", "fill_color": {"value": "#F6931F"}, "doc": null}, "type": "Circle", "id": "e7239980-5faf-4dfc-bb9c-d4046a0adebd"}, {"attributes": {"x": {"field": "fertility"}, "tags": [], "y": {"field": "life"}, "l ...

# %%
from bokeh._version import get_versions
get_versions()
# Out:
# {'full': '5ce7a1556b2fa2c9cc89618c41fc77874fd7ddad',
#  'version': '0.9.1dev.65161924'}
